# %%
4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# Out:
# Object `for` not found.
# Object `images` not found.
# Object `work` not found.
# Object `it` not found.
# Object `code` not found.

# %% [markdown]
# # 1. What does RGBA stand for?

# %% [markdown]
# ==>RED,GREEN,BLUE,ALPHA it is ued for the colors combination for any components.

# %% [markdown]
# # 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from collections import Counter
imgobj = Image.open(r'C:\Users\rohan\OneDrive\Pictures\body size\r1.jpg')
pixels = imgobj.convert('RGBA')
data = imgobj.getdata()
counts = Counter(data)
print(counts)

# %%
counts
# Out:
# Counter({(140, 108, 95): 174,
#          (142, 110, 97): 165,
#          (144, 112, 99): 169,
#          (146, 114, 101): 185,
#          (147, 115, 102): 183,
#          (146, 114, 99): 371,
#          (150, 118, 103): 418,
#          (151, 119, 104): 429,
#          (154, 123, 105): 207,
#          (156, 125, 107): 183,
#          (155, 124, 106): 228,
#          (156, 123, 108): 186,
#          (159, 126, 111): 279,
#          (161, 128, 113): 222,
#          (162, 129, 114): 193,
#          (161, 128, 111): 138,
#          (159, 126, 109): 152,
#          (158, 125, 108): 126,
#          (157, 124, 107): 106,
#          (161, 128, 109): 106,
#          (162, 129, 110): 183,
#          (163, 130, 111): 140,
#          (164, 131, 112): 135,
#          (164, 131, 114): 70,
#          (160, 127, 110): 144,
#          (165, 132, 117): 41,
#          (166, 133, 118): 32,
#          (154, 122, 109): 309,
#          (141, 109, 96): 185,
#          (139, 107, 94): 173,
# ...

# %% [markdown]
# # 3. What is a box tuple, and how does it work?

# %% [markdown]
#  ==>Box tuple is the representation th pixels of the image in the co-ordinate axis.These tuple has four vlues.
# (xl,yl,xr,yr).It has top left of x value at the top and the top left valu of the y first and than it has bottom right
# value of x  and bottom right value of y in the box tuple as it is shoeing on the box.

# %% [markdown]
# # 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
i=Image.open(r'C:\Users\rohan\OneDrive\Pictures\body size\r1.jpg')
i.show()
print(i.show())
# Out:
# None

# %%
i.height
# Out:
# 1280

# %%
i.width
# Out:
# 960

# %% [markdown]
# # 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
box=()
s=i.resize(size=(100,100))
# i=i.crop(box)
s.height
# Out:
# 100

# %%
from PIL import Image
import numpy as np      
  

img = Image.open(r"C:\Users\rohan\OneDrive\Pictures\body size\r1.jpg").convert('RGB')
  

img=img.resize(size=(100,100))
img_arr = np.array(img)

  

img_arr[50 : 100, 0 :50] = (0, 0,0)
  

img = Image.fromarray(img_arr)

img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x11002670>

# %% [markdown]
# # 6. After making changes to an Image object, how could you save it as an image file?

# %%
img.save('pil.jpg')

# %% [markdown]
# # 7. What module contains Pillow’s shape-drawing code?

# %%
from PIL import Image,ImageDraw

image = Image.new('RGBA', (200, 200), 'white')
draw = ImageDraw.Draw(image)
draw.line([(0, 0), (199, 0), (199, 199), (0, 199), (0, 0)], fill='black')
draw.rectangle((20, 30, 60, 60), fill='blue')
draw.ellipse((120, 30, 160, 60), fill='red')
draw.polygon(((57, 87), (79, 62), (94, 85), (120, 90), (103, 113)),fill='brown')

for i in range(100, 200, 10):
 
 draw.line([(i, 0), (200, i - 100)], fill='green')

image.save('drawings.png')

# %% [markdown]
# # 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
with Image.open(<file_path>) as i:
    d=ImageDraw.Draw(i)
    d.line([(0,0)+i.size])
